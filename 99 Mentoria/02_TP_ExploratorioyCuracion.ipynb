# %% [markdown]
# # Practico Mentoria - Analisis Exploratorio y Curación de Datos
# <h3><FONT COLOR="#FF0000"> Alumno: Flavio Olivier (Omega)</FONT></h3>
#
# ---

# %% [markdown]
# ### Importaciones

# %%
#paquetería...

# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sp

from sklearn import preprocessing

import warnings
warnings.filterwarnings('ignore')

# %%
# Set seed for reproducibility
np.random.seed(0)

# %%
#daterio...

path = 'https://raw.githubusercontent.com/diplodatos2019mentoria/Analisis_Exploratorio_Curacion_Datos/master/'

player_df = pd.read_csv(path + 'Datasets/football_player.csv')
team_df = pd.read_csv(path + 'Datasets/football_team.csv')
match_df = pd.read_csv(path + 'Datasets/football_match.csv')

print("Shape 'player_df' = {}".format(player_df.shape))
print("Shape 'team_df'   = {}".format(team_df.shape))
print("Shape 'match_df'  = {}".format(match_df.shape))
# Out:
# Shape 'player_df' = (11060, 40)
# Shape 'team_df'   = (288, 22)
# Shape 'match_df'  = (25979, 12)

# %% [markdown]
# ---

# %% [markdown]
# # 1. Importacion de los datos

# %% [markdown]
# Calculemos el rango de fechas de los partidos

# %%
match_df['date'].max() - match_df['date'].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-b14d418495e8> in <module>
# ----> 1 match_df['date'].max() - match_df['date'].min()
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# Indiquemos que la columna `date` es una fechas como indica la [documentación](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html#datetime-handling)

# %%
# TODO

match_df = pd.read_csv(path + 'Datasets/football_match.csv', parse_dates = ['date'])
match_df['date'].max() - match_df['date'].min()
# Out:
# Timedelta('2868 days 00:00:00')

# %% [markdown]
# # 2. Etiquetas de variables/columnas: no usar caracteres especiales

# %% [markdown]
# Chequar que no haya caracteres fuera de `a-Z`, `0-9` y `_` en los nombres de columnas de los Dataframes:
# * `player_df`
# * `team_df`
# * `match_df`

# %%
# TODO

#caracteres especiales...
import re

def check(col):
    regex = re.match(r'([a-zA-Z0-9_])+$', col)
     
    if regex == None:
        validacion = 'INVALIDO'
    else:
        validacion = 'ok'
    
    return validacion

#side by side...
from IPython.display import display_html

def siamesas(*args):
    html_str = ''
    spaciador = '<table style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table>'
    for df in args:
        html_str += df.to_html() + spaciador
        
    display_html(html_str.replace('table', 'table style = "display:inline"'), raw = True)

# %%
#validamos nombres de columnas...

dfs = []
cols = []
estados = []

for df in ['player_df', 'team_df', 'match_df']:
    for col in pd.eval(df + '.columns'):
        #print(df, col, '->', check(col))
        dfs.append(df)
        cols.append(col)
        estados.append(check(col))

dfs = pd.DataFrame.from_dict({'tabla':dfs, 'columna':cols, 'valida':estados})
siamesas(dfs.loc[dfs.tabla == 'player_df'], dfs.loc[dfs.tabla == 'team_df'], dfs.loc[dfs.tabla == 'match_df'])
# Out:
# <table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>
#       <th>valida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>player_df</td>
#       <td>player name</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>player_df</td>
#       <td>birthday</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>player_df</td>
#       <td>height_m</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>player_df</td>
#       <td>weight_kg</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>player_df</td>
#       <td>overall_rating</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>player_df</td>
#       <td>potential</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>player_df</td>
#       <td>preferred foot</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>player_df</td>
#       <td>crossing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>player_df</td>
#       <td>finishing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>player_df</td>
#       <td>heading accuracy</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>player_df</td>
#       <td>short passing</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>player_df</td>
#       <td>volleys</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>player_df</td>
#       <td>dribbling</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>player_df</td>
#       <td>curve</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>player_df</td>
#       <td>free kick accuracy</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>player_df</td>
#       <td>long passing</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>player_df</td>
#       <td>ball control</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>player_df</td>
#       <td>acceleration</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>player_df</td>
#       <td>sprint speed</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>player_df</td>
#       <td>agility</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>player_df</td>
#       <td>reactions</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>player_df</td>
#       <td>balance</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>player_df</td>
#       <td>shot power</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>player_df</td>
#       <td>jumping</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>player_df</td>
#       <td>stamina</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>player_df</td>
#       <td>strength</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>player_df</td>
#       <td>long shots</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>player_df</td>
#       <td>aggression</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>player_df</td>
#       <td>interceptions</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>player_df</td>
#       <td>positioning</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>player_df</td>
#       <td>vision</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>player_df</td>
#       <td>penalties</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>player_df</td>
#       <td>marking</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>player_df</td>
#       <td>standing tackle</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>player_df</td>
#       <td>sliding tackle</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>player_df</td>
#       <td>gk_diving</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>player_df</td>
#       <td>gk_handling</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>player_df</td>
#       <td>gk_kicking</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>player_df</td>
#       <td>gk_positioning</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>player_df</td>
#       <td>gk_reflexes</td>
#       <td>ok</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>
#       <th>valida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>40</th>
#       <td>team_df</td>
#       <td>team long name</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>team_df</td>
#       <td>team short name</td>
#       <td>INVALIDO</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>team_df</td>
#       <td>buildUpPlaySpeed</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>team_df</td>
#       <td>buildUpPlaySpeedClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>team_df</td>
#       <td>buildUpPlayDribblingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>team_df</td>
#       <td>buildUpPlayPassing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>team_df</td>
#       <td>buildUpPlayPassingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>team_df</td>
#       <td>buildUpPlayPositioningClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>team_df</td>
#       <td>chanceCreationPassing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>team_df</td>
#       <td>chanceCreationPassingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>team_df</td>
#       <td>chanceCreationCrossing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>team_df</td>
#       <td>chanceCreationCrossingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>team_df</td>
#       <td>chanceCreationShooting</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>team_df</td>
#       <td>chanceCreationShootingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>team_df</td>
#       <td>chanceCreationPositioningClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>team_df</td>
#       <td>defencePressure</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>team_df</td>
#       <td>defencePressureClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>team_df</td>
#       <td>defenceAggression</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>team_df</td>
#       <td>defenceAggressionClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>team_df</td>
#       <td>defenceTeamWidth</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>team_df</td>
#       <td>defenceTeamWidthClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>team_df</td>
#       <td>defenceDefenderLineClass</td>
#       <td>ok</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>

# %%
#reeplazamos espacios por '_'...
#... y re-validamos.

player_df.columns = player_df.columns.str.replace(' ', '_')
team_df.columns = team_df.columns.str.replace(' ', '_')
match_df.columns = match_df.columns.str.replace(' ', '_')

#

dfs = []
cols = []
estados = []

for df in ['player_df', 'team_df', 'match_df']:
    for col in pd.eval(df + '.columns'):
        #print(df, col, '->', check(col))
        dfs.append(df)
        cols.append(col)
        estados.append(check(col))

dfs = pd.DataFrame.from_dict({'tabla':dfs, 'columna':cols, 'valida':estados})
siamesas(dfs.loc[dfs.tabla == 'player_df'], dfs.loc[dfs.tabla == 'team_df'], dfs.loc[dfs.tabla == 'match_df'])
# Out:
# <table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>
#       <th>valida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>player_df</td>
#       <td>player_name</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>player_df</td>
#       <td>birthday</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>player_df</td>
#       <td>height_m</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>player_df</td>
#       <td>weight_kg</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>player_df</td>
#       <td>overall_rating</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>player_df</td>
#       <td>potential</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>player_df</td>
#       <td>preferred_foot</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>player_df</td>
#       <td>crossing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>player_df</td>
#       <td>finishing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>player_df</td>
#       <td>heading_accuracy</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>player_df</td>
#       <td>short_passing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>player_df</td>
#       <td>volleys</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>player_df</td>
#       <td>dribbling</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>player_df</td>
#       <td>curve</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>player_df</td>
#       <td>free_kick_accuracy</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>player_df</td>
#       <td>long_passing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>player_df</td>
#       <td>ball_control</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>player_df</td>
#       <td>acceleration</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>player_df</td>
#       <td>sprint_speed</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>player_df</td>
#       <td>agility</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>player_df</td>
#       <td>reactions</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>player_df</td>
#       <td>balance</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>player_df</td>
#       <td>shot_power</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>player_df</td>
#       <td>jumping</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>player_df</td>
#       <td>stamina</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>player_df</td>
#       <td>strength</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>player_df</td>
#       <td>long_shots</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>player_df</td>
#       <td>aggression</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>player_df</td>
#       <td>interceptions</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>player_df</td>
#       <td>positioning</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>player_df</td>
#       <td>vision</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>player_df</td>
#       <td>penalties</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>player_df</td>
#       <td>marking</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>player_df</td>
#       <td>standing_tackle</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>player_df</td>
#       <td>sliding_tackle</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>player_df</td>
#       <td>gk_diving</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>player_df</td>
#       <td>gk_handling</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>player_df</td>
#       <td>gk_kicking</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>player_df</td>
#       <td>gk_positioning</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>player_df</td>
#       <td>gk_reflexes</td>
#       <td>ok</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>
#       <th>valida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>40</th>
#       <td>team_df</td>
#       <td>team_long_name</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>team_df</td>
#       <td>team_short_name</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>team_df</td>
#       <td>buildUpPlaySpeed</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>team_df</td>
#       <td>buildUpPlaySpeedClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>team_df</td>
#       <td>buildUpPlayDribblingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>team_df</td>
#       <td>buildUpPlayPassing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>team_df</td>
#       <td>buildUpPlayPassingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>team_df</td>
#       <td>buildUpPlayPositioningClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>team_df</td>
#       <td>chanceCreationPassing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>team_df</td>
#       <td>chanceCreationPassingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>50</th>
#       <td>team_df</td>
#       <td>chanceCreationCrossing</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>51</th>
#       <td>team_df</td>
#       <td>chanceCreationCrossingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>team_df</td>
#       <td>chanceCreationShooting</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>53</th>
#       <td>team_df</td>
#       <td>chanceCreationShootingClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>team_df</td>
#       <td>chanceCreationPositioningClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>55</th>
#       <td>team_df</td>
#       <td>defencePressure</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>56</th>
#       <td>team_df</td>
#       <td>defencePressureClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>57</th>
#       <td>team_df</td>
#       <td>defenceAggression</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>58</th>
#       <td>team_df</td>
#       <td>defenceAggressionClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>59</th>
#       <td>team_df</td>
#       <td>defenceTeamWidth</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>60</th>
#       <td>team_df</td>
#       <td>defenceTeamWidthClass</td>
#       <td>ok</td>
#     </tr>
#     <tr>
#       <th>61</th>
#       <td>team_df</td>
#       <td>defenceDefenderLineClass</td>
#       <td>ok</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>tabla</th>
#       <th>columna</th>
#       <th>valida</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>62</th>

# %% [markdown]
# # 3. Agregar nuevas caracteristicas

# %% [markdown]
# Agregar al Dataframe `player_df` una nueva columna que sea `imc` correspondiente al **Indice de Masa Corporal**
#
# Link:
# * https://www.texasheart.org/heart-health/heart-information-center/topics/calculadora-del-indice-de-masa-corporal-imc/

# %%
# TODO

if 'IMC' in player_df.columns:
    player_df.drop('IMC', axis = 1, inplace = True)
    
player_df.insert(4, 'IMC', player_df['weight_kg'] / player_df['height_m']**2)
player_df.head()
# Out:
#           player_name    birthday  height_m  weight_kg        IMC  \
# 0  Aaron Appindangoye  1992-02-29      1.83      84.82  25.327720
# 1     Aaron Cresswell  1989-12-15      1.70      66.22  22.913495
# 2         Aaron Doran  1991-05-13      1.70      73.94  25.584775
# 3       Aaron Galindo  1982-05-08      1.83      89.81  26.817761
# 4        Aaron Hughes  1979-11-08      1.83      69.85  20.857595
#
#    overall_rating  potential preferred_foot  crossing  finishing     ...       \
# 0           63.60      67.60          right     48.60      43.60     ...
# 1           66.97      74.48           left     70.79      49.45     ...
# 2           67.00      74.19          right     68.12      57.92     ...
# 3           69.09      70.78          right     57.22      26.26     ...
# 4           73.24      74.68          right     45.08      38.84     ...
#
#    vision  penalties  marking  standing_tackle  sliding_tackle  gk_diving  \
# 0   53.60      47.60    63.80            66.00           67.80       5.60
# 1   57.45      53.12    69.39            68.79           71.52      12.18
# 2   69.38      60.54    22.04            21.12           21.35      14.04
# 3   53.78      41.74    70.61            70.65           68.04      14.17
# 4   46.48      52.96    77.60            76.04           74.60       8.28
#
#    gk_handling  gk_kicking  gk_positioning  gk_reflexes
# 0        10.60        9.60            7.60         7.60
# 1         8.67       14.24           10.36        12.91
# 2        11.81       17.73           10.12        13.50
# 3        11.17       22.87           11.17        10.17
# 4         8.32       24.92           12.84        11.92
#
# [5 rows x 41 columns]

# %% [markdown]
# # 4. Tratar valores faltantes

# %% [markdown]
# Veamos cuantos valores nulos tenemos

# %%
player_missing_values_count = player_df.isnull().sum()

player_missing_values_count[player_missing_values_count > 0]
# Out:
# volleys           478
# curve             478
# agility           478
# balance           478
# jumping           478
# vision            478
# sliding_tackle    478
# dtype: int64

# %%
team_missing_values_count = team_df.isnull().sum()

team_missing_values_count[team_missing_values_count > 0]
# Out:
# Series([], dtype: int64)

# %%
match_missing_values_count = match_df.isnull().sum()

match_missing_values_count[match_missing_values_count > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Algunas tecnicas para tratar los _missing values_:
# * **Eliminar** muestras o variables que tienen datos faltantes.
# * **Imputar** los valores perdidos, es decir, sustituirlos por estimaciones por ejemplo la `media`, la `moda` ó usando `KNN`.
#
# A) Analizar si es conveniente **Eliminar** las muestras o variables con datos faltantes del Dataframe `player_df`.
#
# B) Aplicar la **Imputacion** usando la `media` o `moda` sobre las columnas con _missing values_ del Dataframe `player_df`.
#
# **Hint**:
# * Para la imputacion usando la `media`, `moda` ver el siguiente link:
#     https://pandas.pydata.org/pandas-docs/stable/user_guide/missing_data.html

# %% [markdown]
# ### ¿Eliminar los _missing values_? Justificar

# %%
#registros NaN's...

player_df_NaNs = player_df[list(player_df.isnull().sum()[player_df.isnull().sum() > 0].index)][player_df.volleys.isnull()]
player_df_NaNs
# Out:
#        volleys  curve  agility  balance  jumping  vision  sliding_tackle
# 25         NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 30         NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 31         NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 83         NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 85         NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 175        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 190        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 203        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 253        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 275        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 289        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 343        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 379        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 405        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 456        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 476        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 485        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 534        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 577        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 584        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 655        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 675        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 713        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 756        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 774        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 798        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 804        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 827        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 885        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 887        NaN    NaN      NaN      NaN      NaN     NaN             NaN
# ...        ...    ...      ...      ...      ...     ...             ...
# 10449      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10475      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10499      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10504      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10528      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10545      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10575      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10627      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10640      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10670      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10671      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10674      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10684      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10692      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10696      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10711      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10738      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10742      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10757      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10802      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10894      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10909      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10913      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10924      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10934      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10949      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 10978      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 11020      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 11024      NaN    NaN      NaN      NaN      NaN     NaN             NaN
# 11027      NaN    NaN      NaN      NaN      NaN     NaN             NaN
#
# [478 rows x 7 columns]

# %%
#porcentaje de registros NaN sobre player_df...

print('Porcentual de valores nulos sobre el universo player_df: {:.2f}%'.format(player_df_NaNs.shape[0] / player_df.shape[0] * 100))
# Out:
# Porcentual de valores nulos sobre el universo player_df: 4.32%

# %% [markdown]
# <h5><FONT COLOR="#FF0000"> La opción de eliminar los registros puede ser viable, representan menos del 5% del universo... aunque podríamos intentar una estrategia que evitara esto con K vecinos más cercanos.</FONT></h5>

# %% [markdown]
# ### Imputacion usando Media y Moda

# %%
#estimamos media de las columnas NaN's...

player_df[player_df_NaNs.columns].mean()
# Out:
# volleys           47.110973
# curve             50.423617
# agility           64.409834
# balance           64.475489
# jumping           66.038396
# vision            55.866959
# sliding_tackle    47.124626
# dtype: float64

# %%
#imputamos media a los valores NaN's...

player_df[player_df_NaNs.columns] = player_df[player_df_NaNs.columns].fillna(player_df[player_df_NaNs.columns].mean())

player_missing_values_count = player_df.isnull().sum()
player_missing_values_count[player_missing_values_count > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# # 5. Normalizacion de columnas

# %% [markdown]
# Primero que todo la notación:
# * $x = [x_1, x_2, ..., x_n]$
# * $\mu$: Media
# * $\sigma$: Desviacion Estandar
#
# Ahora normalizaremos algunas de las columnas del Dataframe, para ello usaremos dos tipos de normalizacion:
#
# * Min-Max:
# $$
# z_i = \frac{x_i - min(x)}{max(x) - min(x)}
# $$
# * Z-score
# $$
# z_i = \frac{x_i - \mu}{\sigma}
# $$
#
# Normalizar la columna `crossing` usando **Min-Max**.
#
# Normalizar la columna `short_passing` usando **Z-score**.
#
# **Hints**:
# * https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.MinMaxScaler.html#sklearn.preprocessing.MinMaxScaler
# * https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.zscore.html

# %% [markdown]
# ### Min-Max

# %%
# TODO
from sklearn.preprocessing import MinMaxScaler

pre = player_df['crossing'].head().copy()
minmaxscaler = MinMaxScaler()
player_df['crossing'] = minmaxscaler.fit_transform(player_df['crossing'].values.reshape(-1, 1))
pos = player_df['crossing'].head().copy()

siamesas(pd.DataFrame(pre).rename(columns={'crossing': 'crossing(pre)'}), pd.DataFrame(pos).rename(columns={'crossing': 'crossing(pos)'}))
# Out:
# <table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crossing(pre)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>48.60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>70.79</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>68.12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>57.22</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>45.08</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>crossing(pos)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.511036</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.777231</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.745202</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.614443</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.468810</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline">

# %% [markdown]
# ### Z-score

# %%
# TODO
from scipy import stats

pre = player_df['short_passing'].head().copy()
player_df['short_passing'] = stats.zscore(player_df['short_passing'])
pos = player_df['short_passing'].head().copy()

siamesas(pd.DataFrame(pre).rename(columns={'short_passing': 'short_passing(pre)'}), pd.DataFrame(pos).rename(columns={'short_passing': 'short_passing(pos)'}))
# Out:
# <table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>short_passing(pre)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>60.60</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>62.27</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>65.12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>64.70</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>64.76</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline"><table style = "display:inline" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>short_passing(pos)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.017238</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.140868</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.351853</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.320761</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.325202</td>
#     </tr>
#   </tbody>
# </table style = "display:inline"><table style = "display:inline" style="min-width: 30px !important;"><tr style="min-width: 30px !important; background:none !important;"><td style="min-width: 30px !important;"></td></tr></table style = "display:inline">

# %% [markdown]
# # 6. Codificar variables

# %% [markdown]
# > Las variables categóricas deben ser etiquetadas como variables numéricas, no como cadenas.
#
# Codificar la variable `country_name` del Dataframe `match_df`

# %%
# TODO

match_df.country_name.value_counts()
# Out:
# England        3040
# France         3040
# Spain          3040
# Italy          3017
# Netherlands    2448
# Germany        2448
# Portugal       2052
# Poland         1920
# Scotland       1824
# Belgium        1728
# Switzerland    1422
# Name: country_name, dtype: int64

# %% [markdown]
# More about preprocessing in:
# * https://scikit-learn.org/stable/modules/classes.html#module-sklearn.preprocessing

# %%
#
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
xx = le.fit_transform(match_df['country_name'])

if 'country_name_le' in match_df.columns:
    match_df.drop('country_name_le', axis = 1, inplace = True)

match_df.insert(0, 'country_name_le', xx)

set(zip(le.classes_, le.transform(le.classes_)))
# Out:
# {('Belgium', 0),
#  ('England', 1),
#  ('France', 2),
#  ('Germany', 3),
#  ('Italy', 4),
#  ('Netherlands', 5),
#  ('Poland', 6),
#  ('Portugal', 7),
#  ('Scotland', 8),
#  ('Spain', 9),
#  ('Switzerland', 10)}

# %%
match_df
# Out:
#        country_name_le country_name               league_name     season  \
# 0                    0      Belgium    Belgium Jupiler League  2008/2009
# 1                    0      Belgium    Belgium Jupiler League  2008/2009
# 2                    0      Belgium    Belgium Jupiler League  2008/2009
# 3                    0      Belgium    Belgium Jupiler League  2008/2009
# 4                    0      Belgium    Belgium Jupiler League  2008/2009
# 5                    0      Belgium    Belgium Jupiler League  2008/2009
# 6                    0      Belgium    Belgium Jupiler League  2008/2009
# 7                    0      Belgium    Belgium Jupiler League  2008/2009
# 8                    0      Belgium    Belgium Jupiler League  2008/2009
# 9                    0      Belgium    Belgium Jupiler League  2008/2009
# 10                   0      Belgium    Belgium Jupiler League  2008/2009
# 11                   0      Belgium    Belgium Jupiler League  2008/2009
# 12                   0      Belgium    Belgium Jupiler League  2008/2009
# 13                   0      Belgium    Belgium Jupiler League  2008/2009
# 14                   0      Belgium    Belgium Jupiler League  2008/2009
# 15                   0      Belgium    Belgium Jupiler League  2008/2009
# 16                   0      Belgium    Belgium Jupiler League  2008/2009
# 17                   0      Belgium    Belgium Jupiler League  2008/2009
# 18                   0      Belgium    Belgium Jupiler League  2008/2009
# 19                   0      Belgium    Belgium Jupiler League  2008/2009
# 20                   0      Belgium    Belgium Jupiler League  2008/2009
# 21                   0      Belgium    Belgium Jupiler League  2008/2009
# 22                   0      Belgium    Belgium Jupiler League  2008/2009
# 23                   0      Belgium    Belgium Jupiler League  2008/2009
# 24                   0      Belgium    Belgium Jupiler League  2008/2009
# 15           KSV Cercle Brugge                  CEB               0
# 16                    KRC Genk                  GEN               1
# 17              RSC Anderlecht                  AND               1
# 18            Sporting Lokeren                  LOK               2
# 19        Royal Excel Mouscron                  MOU               0
# 20              Club Brugge KV                  CLB               2
# 21            SV Zulte-Waregem                  ZUL               2
# 22               FCV Dender EH                  DEN               1
# 23                      Tubize                  TUB               1
# 24                 KV Mechelen                  MEC               0
# 25                    KRC Genk                  GEN               1
# 26           Standard de Liège                  STL               1
# 27              RSC Anderlecht                  AND               1
# 28               KSV Roeselare                  ROS               1
# 29                Beerschot AC                  BAC               2
# ...                        ...                  ...             ...
# 25949                   Lugano                  LUG               6
# 25950                 FC Basel                  BAS               1
# 25951                FC Zürich                  ZUR               0
# 25952                  FC Sion                  SIO               1
# 25953                  FC Thun                  THU               3
# 25954                  FC Thun                  THU               3
# 25955                   Lugano                  LUG               0
# 25956            FC St. Gallen                  GAL               0
# 25957                FC Zürich                  ZUR               3
# 25958  Grasshopper Club Zürich                  GRA               3
# 25959                 FC Basel                  BAS               1
# 25960           BSC Young Boys                   YB               1
# 25961  Grasshopper Club Zürich                  GRA               0
# 25962                 FC Vaduz                  VAD               1
# 25963                FC Luzern                  LUZ               2
# 25964                FC Luzern                  LUZ               0
# 25965            FC St. Gallen                  GAL               1
# 25966                  FC Sion                  SIO               0
# 25967                FC Zürich                  ZUR               3
# 25968           BSC Young Boys                   YB               3
# 25969            FC St. Gallen                  GAL               2
# 25970                 FC Vaduz                  VAD               4
# 25971  Grasshopper Club Zürich                  GRA               3
# 25972                  FC Thun                  THU               3
# 25973                   Lugano                  LUG               3
# 25974                  FC Thun                  THU               1
# 25975                FC Luzern                  LUZ               1
# 25976                  FC Sion                  SIO               2
# 25977                FC Zürich                  ZUR               0
# 25978                 FC Basel                  BAS               4
#
#        away_team_goal  total_goal
# 0                   1           2
# 1                   0           0
# 2                   3           3
# 3                   0           5
# 4                   3           4
# 5                   1           2
# 6                   2           4
# 7                   2           3
# 8                   0           1
# 9                   1           5
# 10                  2           3
# 11                  2           2
# 12                  0           0
# 13                  2           4
# 14                  2           3
# 15                  1           1
# 16                  3           4
# 17                  3           4
# 18                  3           5
# 19                  0           0
# 20                  2           4
# 21                  0           2
# 22                  1           2
# 23                  2           3
# 24                  0           0
# 25                  0           1
# 26                  3           4
# 27                  1           2
# 28                  1           2
# 29                  2           4
# ...               ...         ...
# 25949               1           7
# 25950               3           4
# 25951               2           2
# 25952               1           2
# 25953               1           4
# 25954               1           4
# 25955               1           1
# 25956               1           1
# 25957               1           4
# 25958               3           6
# 25959               3           4
# 25960               3           4
# 25961               2           2
# 25962               0           1
# 25963               5           7
# 25964               1           1
# 25965               0           1
# 25966               2           2
# 25967               1           4
# 25968               2           5
# 25969               1           3
# 25970               0           4
# 25971               3           6
# 25972               3           6
# 25973               0           3
# 25974               0           1
# 25975               2           3
# 25976               0           2
# 25977               0           0
# 25978               3           7
#
# [25979 rows x 13 columns]
